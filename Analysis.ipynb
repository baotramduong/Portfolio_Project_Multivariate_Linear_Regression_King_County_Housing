# %%
#import all necessary packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
sns.set(style="whitegrid")

import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms

import scipy.stats as stats

from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import pickle

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Q1: What features adds value to a home?**
#
# **Q2: What features decreases value of a home?**
#
# **Q3: What features are nice to have but have no effect on the values of a home?**
#
# **Q4: How does location affect the price of a home?**
#
# **Q5: What are the most predictive features to predict the price of a home?**

# %%
#read dataframe
summary_table_1 = pd.read_csv('./Data & Figures/summary_table_1', index_col = 0)
summary_table_1.head()
# Out:
#      Model                          Description   Num Features        r2  \
# 0  Model A                         All features           22.0  0.671319
# 1  Model B  All features, outliers removed, RFE           13.0  0.645805
# 2  Model C                   Poly, All features           21.0  0.586662
# 3  Model D           Log features, All features           21.0  0.605890
#
#    Accuracy Multicollinearity Normality Homoscedasticity  Cross Validation
# 0      66.0                 P         F                F         -0.333676
# 1      66.0                 P         F                F         -0.271099
# 2      57.0                 P         F                F         -0.337328
# 3      58.0                 P         F                F         -0.397877

# %%
#read dataframe
summary_table_2 = pd.read_csv('./Data & Figures/summary_table_2', index_col = 0)
summary_table_2.head()
# Out:
#      Model                       Description   Num Features        r2  \
# 0  Model 1      Log, All features - location           13.0  0.583683
# 1  Model 2      Log, All features + location           23.0  0.765911
# 2  Model 3    Log, Recursive Feature Ranking           10.0  0.765911
# 3  Model 4  Log, All features + Interactions           23.0  0.733888
# 4  Model 5           Log, Poly, Interactions           23.0  0.668486
#
#    Accuracy Multicollinearity Normality Homoscedasticity  Cross Validation
# 0      60.0                 P         P                P         -0.418562
# 1      77.0                 P         P                P         -0.236650
# 2      77.0                 P         P                P         -0.288733
# 3      74.0                 P         P                P         -0.269521
# 4      68.0                 P         P                P         -0.336123

# %%
#load model from Pickle
Pkl_Filename = "./Data & Figures/model_2.pkl"  

with open(Pkl_Filename, 'rb') as file:  
    Pickled_LR_Model = pickle.load(file)

Pickled_LR_Model
# Out:
# (LinearRegression(),
#         bedrooms  bathrooms  zip_A  zip_F  sqft_lot_log  zip_C  zip_B  zip_G  \
#  8539          4       2.50      0      1     -0.263540      0      0      0
#  21591         3       2.50      1      0     -2.018227      0      0      0
#  5539          4       2.75      0      0      0.055181      0      0      1
#  7797          4       1.50      0      0      0.197012      0      1      0
#  11752         6       2.25      0      0      0.369521      0      1      0
#  ...         ...        ...    ...    ...           ...    ...    ...    ...
#  19798         5       4.50      0      0      0.007718      0      1      0
#  9228          2       1.00      1      0      0.227977      0      0      0
#  5431          3       2.50      1      0     -0.288324      0      0      0
#  8847          5       3.25      0      0     -0.138375      0      0      0
#  1505          4       2.50      0      1     -0.150479      0      0      0
#
#         sqft_living15_log  sqft_above_log  ...  zip_I  cond_3.0  zip_E  \
#  8539           -0.053329        0.815523  ...      0         1      0
#  21591          -1.061167       -0.756736  ...      0         1      0
#  5539            0.816985        0.711940  ...      0         1      0
#  7797           -0.188334        0.501532  ...      0         0      0
#  11752          -0.154019        0.097850  ...      0         0      0
#  ...                  ...             ...  ...    ...       ...    ...
#  19798           2.377043        1.720231  ...      0         1      0
#  9228           -0.103259       -0.494314  ...      0         1      0
#  5431            0.091743       -0.476649  ...      0         1      0
#  8847            1.044197        1.189320  ...      0         1      0
#  1505            0.391394        0.406949  ...      0         0      0
#
#         zipcode  cond_2.0  reno_1.0  cond_5.0  zip_D  zip_H  floors
#  8539     98092         0         0         0      0      0     2.0
#  21591    98116         0         0         0      0      0     2.0
#  5539     98075         0         0         0      0      0     2.0
#  7797     98034         0         0         0      0      0     2.0
#  11752    98072         0         0         0      0      0     1.0
#  ...        ...       ...       ...       ...    ...    ...     ...
#  19798    98033         0         0         0      0      0     2.0
#  9228     98136         0         0         0      0      0     1.0
#  5431     98155         0         0         0      0      0     1.0
#  8847     98038         0         0         0      0      1     2.0
#  1505     98001         0         0         0      0      0     1.0
#
#  [17136 rows x 23 columns],
#  8539    -0.654784
#  21591    0.038930
#  5539     0.442162
#  7797    -0.026332
#  11752   -0.312342
#             ...
#  19798    2.266810
#  9228     0.777486
#  5431    -0.411307
#  8847     0.018775
#  1505    -0.515697
#  Name: price_log, Length: 17136, dtype: float64)

# %% [markdown]
# # Q1: What features adds value to a home?

# %% [markdown]
# # Q2: What features decreases value of a home?

# %% [markdown]
# # Q3: What features are nice to have but have no effect on the values of a home?

# %% [markdown]
# # Q4: How does location affect the price of a home?

# %% [markdown]
# # Q5: What are the most predictive features to predict the price of a home?
